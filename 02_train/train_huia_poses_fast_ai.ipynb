# %% [markdown]
# # 02 Huia Experience Training

# %% [markdown]
# ### Reference
# https://www.tensorflow.org/alpha/tutorials/load_data/images

# %% [markdown]
# ## TODOS
# - not using variable learning rates => keras extension ---
# - LRFinder
# - interpret layers visually
# - tensorboard convergence

# %% [markdown]
# # Setup
# ## Install FastAI

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64
import pathlib
from pathlib import Path
#import tensorboard as tb

# %% [markdown]
# # Data
# We have to understand well our data as this is fundamental to achieve good results.

# %%
root_path = pathlib.Path("./training_data/")
image_path = root_path /"images"
json_path = root_path /"json"
image_path,json_path
# Out:
# (PosixPath('training_data/images'), PosixPath('training_data/json'))

# %%
# lets set the random seed so we can reproduce our results
import random
random.seed(7)
# get filenames from directories
all_image_paths = list(image_path.glob('*.png'))

#all_image_paths = [path for path in all_image_paths] # convert to strings
#random.shuffle(all_image_paths) # randomize

# %%
type(all_image_paths)
#len(all_image_paths)
# Out:
# list

# %%
all_image_paths[:20]
# Out:
# [PosixPath('training_data/images/normal_811.png'),
#  PosixPath('training_data/images/dramatic_297.png'),
#  PosixPath('training_data/images/wings_425.png'),
#  PosixPath('training_data/images/wings_417.png'),
#  PosixPath('training_data/images/hadouken_1237.png'),
#  PosixPath('training_data/images/wings_220.png'),
#  PosixPath('training_data/images/hadouken_967.png'),
#  PosixPath('training_data/images/wings_37.png'),
#  PosixPath('training_data/images/moonwalk_74.png'),
#  PosixPath('training_data/images/moonwalk_250.png'),
#  PosixPath('training_data/images/dramatic_1256.png'),
#  PosixPath('training_data/images/hadouken_262.png'),
#  PosixPath('training_data/images/dramatic_555.png'),
#  PosixPath('training_data/images/normal_208.png'),
#  PosixPath('training_data/images/underarm_460.png'),
#  PosixPath('training_data/images/normal_815.png'),
#  PosixPath('training_data/images/wings_423.png'),
#  PosixPath('training_data/images/backpack_526.png'),
#  PosixPath('training_data/images/fly_437.png'),
#  PosixPath('training_data/images/dramatic_1251.png')]

# %%
import re
# extract categories for classification
pat = r'/([^/]+)_\d+.png$'
all_image_labels = [str(re.search(pat,str(image)).group(1)).lower() for image in all_image_paths]
all_image_labels
# Out:
# ['normal',
#  'dramatic',
#  'wings',
#  'wings',
#  'hadouken',
#  'wings',
#  'hadouken',
#  'wings',
#  'moonwalk',
#  'moonwalk',
#  'dramatic',
#  'hadouken',
#  'dramatic',
#  'normal',
#  'underarm',
#  'normal',
#  'wings',
#  'backpack',
#  'fly',
#  'dramatic',
#  'dramatic',
#  'moonwalk',
#  'dramatic',
#  'moonwalk',
#  'backpack',
#  'hadouken',
#  'underarm',
#  'wings',
#  'underarm',
#  'hadouken',
#  'fly',
#  'fly',
#  'dramatic',
#  'underarm',
#  'normal',
#  'underarm',
#  'dramatic',
#  'normal',
#  'dramatic',
#  'wings',
#  'normal',
#  'dramatic',
#  'wings',
#  'normal',
#  'wings',
#  'backpack',
#  'fly',
#  'underarm',
#  'dramatic',
#  'fly',
#  'backpack',
#  'fly',
#  'normal',
#  'normal',
#  'normal',
#  'underarm',
#  'dramatic',
#  'hadouken',
#  'backpack',
#  'moonwalk',
#  'backpack',
#  'moonwalk',
#  'moonwalk',
#  'moonwalk',
#  'fly',
#  'moonwalk',
#  'dramatic',
#  'backpack',
#  'dramatic',
#  'underarm',
#  'moonwalk',
#  'hadouken',
#  'normal',
#  'moonwalk',
#  'fly',
#  'backpack',
#  'moonwalk',
#  'dramatic',
#  'fly',
#  'hadouken',
#  'underarm',
#  'hadouken',
#  'normal',
#  'wings',
#  'normal',
#  'dramatic',
#  'normal',
#  'underarm',
#  'fly',
#  'normal',
#  'fly',
#  'moonwalk',
#  'fly',
#  'underarm',
#  'moonwalk',
#  'hadouken',
#  'hadouken',
#  'moonwalk',
#  'dramatic',
#  'fly',
#  'fly',
#  'dramatic',
#  'dramatic',
#  'wings',
#  'normal',
#  'normal',
#  'dramatic',
#  'wings',
#  'hadouken',
#  'dramatic',
#  'moonwalk',
#  'moonwalk',
#  'wings',
#  'moonwalk',
#  'underarm',
#  'normal',
#  'moonwalk',
#  'normal',
#  'hadouken',
#  'normal',
#  'normal',
#  'moonwalk',
#  'wings',
#  'dramatic',
#  'backpack',
#  'underarm',
#  'wings',
#  'fly',
#  'hadouken',
#  'dramatic',
#  'dramatic',
#  'fly',
#  'normal',
#  'fly',
#  'hadouken',
#  'moonwalk',
#  'normal',
#  'fly',
#  'backpack',
#  'normal',
#  'normal',
#  'normal',
#  'hadouken',
#  'fly',
#  'dramatic',
#  'wings',
#  'dramatic',
#  'underarm',
#  'dramatic',
#  'backpack',
#  'normal',
#  'fly',
#  'dramatic',
#  'underarm',
#  'moonwalk',
#  'underarm',
#  'hadouken',
#  'backpack',
#  'fly',
#  'backpack',
#  'fly',
#  'wings',
#  'fly',
#  'normal',
#  'hadouken',
#  'fly',
#  'normal',
#  'underarm',
#  'underarm',
#  'dramatic',
#  'moonwalk',
#  'normal',
#  'underarm',
#  'moonwalk',
#  'wings',
#  'wings',
#  'dramatic',
#  'fly',
#  'moonwalk',
#  'fly',
#  'backpack',
#  'wings',
#  'hadouken',
#  'fly',
#  'underarm',
#  'fly',
#  'moonwalk',
#  'wings',
#  'wings',
#  'dramatic',
#  'backpack',
#  'underarm',
#  'hadouken',
#  'fly',
#  'hadouken',
#  'underarm',
#  'dramatic',
#  'normal',
#  'normal',
#  'dramatic',
#  'fly',
#  'normal',
#  'fly',
#  'normal',
#  'normal',
#  'fly',
#  'backpack',
#  'dramatic',
#  'fly',
#  'normal',
#  'fly',
#  'backpack',
#  'fly',
#  'normal',
#  'fly',
#  'fly',
#  'hadouken',
#  'backpack',
#  'underarm',
#  'wings',
#  'normal',
#  'moonwalk',
#  'hadouken',
#  'hadouken',
#  'dramatic',
#  'normal',
#  'dramatic',
#  'underarm',
#  'fly',
#  'fly',
#  'fly',
#  'hadouken',
#  'normal',
#  'normal',
#  'dramatic',
#  'normal',
#  'hadouken',
#  'underarm',
#  'normal',
#  'hadouken',
#  'dramatic',
#  'hadouken',
#  'fly',
#  'backpack',
#  'wings',
#  'dramatic',
#  'fly',
#  'hadouken',
#  'fly',
#  'fly',
#  'wings',
#  'dramatic',
#  'underarm',
#  'wings',
#  'normal',
#  'underarm',
#  'dramatic',
#  'hadouken',
#  'normal',
#  'underarm',
#  'moonwalk',
#  'dramatic',
#  'normal',
#  'backpack',
#  'fly',
#  'dramatic',
#  'normal',
#  'underarm',
#  'underarm',
#  'underarm',
#  'dramatic',
#  'moonwalk',
#  'normal',
#  'normal',
#  'hadouken',
#  'fly',
#  'dramatic',
#  'fly',
#  'wings',
#  'normal',
#  'normal',
#  'moonwalk',
#  'normal',
#  'fly',
#  'moonwalk',
#  'dramatic',
#  'wings',
#  'normal',
#  'normal',
#  'underarm',
#  'wings',
#  'backpack',
#  'normal',
#  'wings',
#  'moonwalk',
#  'hadouken',
#  'hadouken',
#  'hadouken',
#  'moonwalk',
#  'moonwalk',
#  'backpack',
#  'fly',
#  'dramatic',
#  'dramatic',
#  'normal',
#  'normal',
#  'normal',
#  'wings',
#  'hadouken',
#  'dramatic',
#  'dramatic',
#  'dramatic',
#  'backpack',
#  'fly',
#  'wings',
#  'hadouken',
#  'underarm',
#  'wings',
#  'moonwalk',
#  'fly',
#  'moonwalk',
#  'dramatic',
#  'hadouken',
#  'hadouken',
#  'underarm',
#  'hadouken',
#  'moonwalk',
#  'wings',
#  'wings',
#  'normal',
#  'fly',
#  'hadouken',
#  'fly',
#  'moonwalk',
#  'wings',
#  'fly',
#  'backpack',
#  'hadouken',
#  'hadouken',
#  'hadouken',
#  'fly',
#  'normal',
#  'fly',
#  'wings',
#  'fly',
#  'fly',
#  'dramatic',
#  'dramatic',
#  'moonwalk',
#  'fly',
#  'fly',
#  'hadouken',
#  'dramatic',
#  'underarm',
#  'hadouken',
#  'hadouken',
#  'fly',
#  'fly',
#  'normal',
#  'moonwalk',
#  'wings',
#  'underarm',
#  'dramatic',
#  'underarm',
#  'dramatic',
#  'moonwalk',
#  'normal',
#  'moonwalk',
#  'hadouken',
#  'hadouken',
#  'normal',
#  'normal',
#  'wings',
#  'backpack',
#  'moonwalk',
#  'hadouken',
#  'hadouken',
#  'hadouken',
#  'underarm',
#  'fly',
#  'fly']

# %%
type(models.resnet101)
# Out:
# function

# %%
# include transforms we can use (rotate, warp)
# transforms=[rand_resize_crop(224,1.3,(0.85,1.23),jitter(0.01),perspective_warp(),
#                              rotate(),skew()]



data = ImageDataBunch.from_name_re(image_path, all_image_paths, pat, 
                                   ds_tfms=get_transforms
                                   (do_flip=False, 
                                    flip_vert=False, 
                                    max_rotate=4, 
                                    max_zoom=1.1, 
                                    max_lighting=None, 
                                    max_warp=0.2, 
                                    p_affine=0.3, 
                                    p_lighting=0) ,
                                    size=224, bs=bs
                                  ).normalize(imagenet_stats)
# Out:
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]

# %%
data.show_batch(rows=3, figsize=(7,6))
# Out:
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-66824b983385> in <module>
# ----> 1 data.show_batch(rows=3, figsize=(7,6))
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/basic_data.py in show_batch(self, rows, ds_type, reverse, **kwargs)
#     183     def show_batch(self, rows:int=5, ds_type:DatasetType=DatasetType.Train, reverse:bool=False, **kwargs)->None:
#     184         "Show a batch of data in `ds_type` on a few `rows`."
# --> 185         x,y = self.one_batch(ds_type, True, True)
#     186         if reverse: x,y = x.flip(0),y.flip(0)
#     187         n_items = rows **2 if self.train_ds.x._square_show else rows
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/basic_data.py in one_batch(self, ds_type, detach, denorm, cpu)
#     166         w = self.num_workers
#     167         self.num_workers = 0
# --> 168         try:     x,y = next(iter(dl))
#     169         finally: self.num_workers = w
#     170         if detach: x,y = to_detach(x,cpu=cpu),to_detach(y,cpu=cpu)
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     580                 self.reorder_dict[idx] = batch
#     581                 continue
# --> 582             return self._process_next_batch(batch)
#     583
#     584     next = __next__  # Python 2 compatibility
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _process_next_batch(self, batch)
#     606                 raise Exception("KeyError:" + batch.exc_msg)
#     607             else:
# --> 608                 raise batch.exc_type(batch.exc_msg)
#     609         return batch
#     610
#
# RuntimeError: Traceback (most recent call last):
#   File "/home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/utils/data/_utils/pin_memory.py", line 41, in _pin_memory_loop
#     batch = pin_memory_batch(batch)
#   File "/home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/utils/data/_utils/pin_memory.py", line 58, in pin_memory_batch
#     return [pin_memory_batch(sample) for sample in batch]
#   File "/home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/utils/data/_utils/pin_memory.py", line 58, in <listcomp>
#     return [pin_memory_batch(sample) for sample in batch]
#   File "/home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/utils/data/_utils/pin_memory.py", line 50, in pin_memory_batch
#     return batch.pin_memory()
# RuntimeError: cuda runtime error (2) : out of memory at /pytorch/aten/src/THC/THCCachingHostAllocator.cpp:265

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['backpack', 'dramatic', 'fly', 'hadouken', 'moonwalk', 'normal', 'underarm', 'wings']
# (8, 8)

# %%
# change for mobilenet
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-b15843901899> in <module>
#       1 # change for mobilenet
# ----> 2 learn = cnn_learner(data, models.resnet34(True), metrics=error_rate)
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/learner.py in cnn_learner(data, base_arch, cut, pretrained, lin_ftrs, ps, custom_head, split_on, bn_final, init, concat_pool, **kwargs)
#      95     meta = cnn_config(base_arch)
#      96     model = create_cnn_model(base_arch, data.c, cut, pretrained, lin_ftrs, ps=ps, custom_head=custom_head,
# ---> 97         split_on=split_on, bn_final=bn_final, concat_pool=concat_pool)
#      98     learn = Learner(data, model, **kwargs)
#      99     learn.split(split_on or meta['split'])
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/learner.py in create_cnn_model(base_arch, nc, cut, pretrained, lin_ftrs, ps, custom_head, split_on, bn_final, concat_pool)
#      81         split_on:Optional[SplitFuncOrIdxList]=None, bn_final:bool=False, concat_pool:bool=True):
#      82     "Create custom convnet architecture"
# ---> 83     body = create_body(base_arch, pretrained, cut)
#      84     if custom_head is None:
#      85         nf = num_features_model(nn.Sequential(*body.children())) * (2 if concat_pool else 1)
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/learner.py in create_body(arch, pretrained, cut)
#      53 def create_body(arch:Callable, pretrained:bool=True, cut:Optional[Union[int, Callable]]=None):
#      54     "Cut off the body of a typically pretrained `model` at `cut` (int) or cut the model as specified by `cut(model)` (function)."
# ---> 55     model = arch(pretrained)
#      56     cut = ifnone(cut, cnn_config(arch)['cut'])
#      57     if cut is None:
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#     148
#     149     def forward(self, x):
# --> 150         x = self.conv1(x)
#     151         x = self.bn1(x)
#     152         x = self.relu(x)
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     336                             _pair(0), self.dilation, self.groups)
#     337         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 338                         self.padding, self.dilation, self.groups)
#     339
#     340
#
# TypeError: conv2d(): argument 'input' (position 1) must be Tensor, not bool

# %%
learn.model
models.resnet34
# Out:
# <function torchvision.models.resnet.resnet34(pretrained=False, **kwargs)>

# %%
learn.lr_find()
#learn.recorder.plot()
# Out:
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# ...
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# /home/ale/anaconda3/envs/tensor20/lib/python3.6/site-packages/fastai/vision/transform.py:243: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   return torch.gesv(B,A)[0][:,0]
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.freeze(:-2)

# %%
learn.fit_one_cycle(20,max_lr=1e-02)

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(20, max_lr=slice(1e-8,1e-7))

# %%
learn.save('fastai_huia_pose')
learn.export('fastai_huia_pose')

# %%
import IPython.display as display
import numpy

# %%
#training_data/images/moonwalk_250.png
img = open_image("training_data/images/moonwalk_250.png")
img.show()
learn.predict(img)

# %% [markdown]
# #Results

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)

# %%
interp.plot_top_losses(9, figsize=(15,11))
#doc(plot_top_losses)

# %%
doc(interp.plot_top_losses)

# %%
interp.plot_confusion_matrix(figsize=(10,10),dpi=60)

# %%
interp.most_confused(min_val=1)

# %% [markdown]
# # Export to Tensorflow

# %%
learn = learn.load("fastai_huia_pose")
import torch
from torch.autograd import Variable

dummy_input = Variable(torch.randn(1,3,224,224)).cuda()
torch.onnx.export(learn.model, dummy_input, "huia.onnx")

# %%
import onnx
from onnx_tf.backend import prepare
# import tensorflow.compat.v1 as tf
# tf.disable_v2_behavior()



onnx_model = onnx.load("huia.onnx")  # load onnx model
output = prepare(onnx_model).run(input)  # run the loaded model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b45d3b956598> in <module>
#       1 import onnx
# ----> 2 from onnx_tf.backend import prepare
#       3 # import tensorflow.compat.v1 as tf
#       4 # tf.disable_v2_behavior()
#       5
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/onnx_tf/__init__.py in <module>
# ----> 1 from . import frontend
#       2 from . import backend
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/onnx_tf/frontend.py in <module>
#      16
#      17 from onnx_tf.common import exception
# ---> 18 from onnx_tf.common.handler_helper import get_all_frontend_handlers
#      19 from onnx_tf.common import IS_PYTHON3
#      20 from onnx_tf.handlers.frontend_handler import FrontendHandler
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/onnx_tf/common/handler_helper.py in <module>
#       3 from onnx import defs
#       4
# ----> 5 from onnx_tf.handlers.backend import *  # noqa
#       6 from onnx_tf.handlers.backend_handler import BackendHandler
#       7 from onnx_tf.handlers.frontend import *  # noqa
#
# ~/anaconda3/envs/tensor20/lib/python3.6/site-packages/onnx_tf/handlers/backend/hardmax.py in <module>
#      10
#      11 @onnx_op("Hardmax")
# ---> 12 @tf_func(tfa.seq2seq.hardmax)
#      13 class Hardmax(BackendHandler):
#      14
#
# AttributeError: module 'tensorflow_addons.seq2seq' has no attribute 'hardmax'

# %%
# other converters MMdnn / pytorch2keras

# %%
import tensorflow as tf

import tensorflowjs as tfjs
tfjs.converters.save_keras_model(model, "models_tfjs/tfjs_huia_mob_224_teste_10_q3",quantization_dtype=np.uint8)

# %% [markdown]
# # Tensorboard

# %%
# %load_ext tensorboard.notebook

#notebook.list() # View open TensorBoard instances
#notebook.display(port=6006, height=1000)

# %%
#!kill 25264
# %tensorboard --logdir ./logs

# %%
import time
default_timeit_steps = 2*steps_per_epoch+1

def timeit(ds, steps=default_timeit_steps):
  overall_start = time.time()
  # Fetch a single batch to prime the pipeline (fill the shuffle buffer),
  # before starting the timer
  it = iter(ds.take(steps+1))
  next(it)

  start = time.time()
  for i,(images,labels) in enumerate(it):
    if i%10 == 0:
      print('.',end='')
  print()
  end = time.time()

  duration = end-start
  print("{} batches: {} s".format(steps, duration))
  print("{:0.5f} Images/s".format(BATCH_SIZE*steps/duration))
  print("Total time: {}s".format(end-overall_start))

# %%
timeit(ds)

# %% [markdown]
# # Predict

# %%
import numpy as np
sample = np.reshape(img_final,[1,224,224,3])

predict = int(model.predict_classes(sample))
predict

# %%
[key for key,value in label_to_index.items() if value == predict]

# %%
label_to_index
